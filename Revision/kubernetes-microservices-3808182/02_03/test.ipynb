# %%
# !kubectl get pods
# Out:
# NAME                              READY   STATUS    RESTARTS      AGE
# hello-minikube-77b6f68484-b884h   1/1     Running   4 (12m ago)   23m

# %%
# !kubectl apply -f echo-server.yaml
# Out:
# deployment.apps/echo-server created
# service/echo-service created

# %%
# !kubectl apply -f learning-resources-api.yaml
# Out:
# deployment.apps/learning-resources created
# service/learning-service created

# %%
# !kubectl get pods
# Out:
# NAME                                  READY   STATUS    RESTARTS      AGE
# echo-server-7cbbfd6bbc-c74q7          1/1     Running   0             46s
# echo-server-7cbbfd6bbc-vl945          1/1     Running   0             46s
# hello-minikube-77b6f68484-b884h       1/1     Running   4 (13m ago)   24m
# learning-resources-578d844d56-44qvl   1/1     Running   0             16s
# learning-resources-578d844d56-s2lvl   1/1     Running   0             16s
# learning-resources-578d844d56-v72hj   1/1     Running   0             16s

# %%
# !kubectl get svc
# Out:
# NAME               TYPE        CLUSTER-IP       EXTERNAL-IP   PORT(S)        AGE
# echo-service       NodePort    10.111.161.220   <none>        80:30076/TCP   84s
# kubernetes         ClusterIP   10.96.0.1        <none>        443/TCP        9h
# learning-service   ClusterIP   10.111.170.172   <none>        80/TCP         54s
