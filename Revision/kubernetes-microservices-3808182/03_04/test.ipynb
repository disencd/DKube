# %%
# !kubectl apply -f frontend-ui.yaml
# Out:
# namespace/frontend unchanged
# deployment.apps/frontend unchanged
# service/frontend-service unchanged

# %%
# !kubectl get svc -n frontend
# Out:
# NAME               TYPE           CLUSTER-IP       EXTERNAL-IP   PORT(S)        AGE
# frontend-service   LoadBalancer   10.109.152.210   <pending>     80:30631/TCP   37h

# %%
# !kubectl apply -f busybox-ui.yaml
# Out:
# pod/busybox-ui created

# %% [markdown]
# / # wget -O- frontend-service | head
# Connecting to frontend-service (10.109.152.210:80)
# writing to stdout
# -                    100% |**********************************************************************************| 12511  0:00:00 ETA
# written to stdout
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>More K8s!</title>
# </head>
#
# / #

# %% [markdown]
# Using the DNS service name to access the service from within the cluster
#
# http://frontend-service.frontend.svc.cluster.local
#
#
# / # wget -O- http://frontend-service.frontend.svc.cluster.local | head
# Connecting to frontend-service.frontend.svc.cluster.local (10.109.152.210:80)
# writing to stdout
# -                    100% |**********************************************************************************| 12511  0:00:00 ETA
# written to stdout
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>More K8s!</title>
# </head>
#
# / #

# %%
# !kubectl get svc -n frontend
# Out:
# NAME               TYPE           CLUSTER-IP       EXTERNAL-IP   PORT(S)        AGE
# frontend-service   LoadBalancer   10.109.152.210   <pending>     80:30631/TCP   37h

# %%
# !kubectl get pods -n frontend
# Out:
# NAME                       READY   STATUS    RESTARTS   AGE
# busybox-ui                 1/1     Running   0          7m24s
# frontend-7b6dbd6f5-ddgqf   1/1     Running   0          37h
# frontend-7b6dbd6f5-gssq8   1/1     Running   0          37h
# frontend-7b6dbd6f5-rgmvz   1/1     Running   0          37h

# %%
# !kubectl port-forward frontend-7b6dbd6f5-ddgqf 4173 80 -n frontend
# Out:
# Forwarding from 127.0.0.1:4173 -> 4173
# Forwarding from [::1]:4173 -> 4173
# Unable to listen on port 80: Listeners failed to create with the following errors: [unable to create listener: Error listen tcp4 127.0.0.1:80: bind: permission denied unable to create listener: Error listen tcp6 [::1]:80: bind: permission denied]
# Handling connection for 4173
# Handling connection for 4173
# Handling connection for 4173
# Handling connection for 4173

# %%
# !kubectl get pods -n frontend -o wide
# Out:
# NAME                       READY   STATUS    RESTARTS   AGE   IP            NODE       NOMINATED NODE   READINESS GATES
# busybox-ui                 1/1     Running   0          13m   10.244.0.42   minikube   <none>           <none>
# frontend-7b6dbd6f5-ddgqf   1/1     Running   0          37h   10.244.0.38   minikube   <none>           <none>
# frontend-7b6dbd6f5-gssq8   1/1     Running   0          37h   10.244.0.39   minikube   <none>           <none>
# frontend-7b6dbd6f5-rgmvz   1/1     Running   0          37h   10.244.0.40   minikube   <none>           <none>
