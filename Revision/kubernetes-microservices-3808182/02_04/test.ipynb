# %%
# !kubectl apply -f frontend-ui.yaml
# Out:
# namespace/frontend created
# deployment.apps/frontend created
# service/frontend-service created

# %%
# !kubectl get pods
# Out:
# NAME                                  READY   STATUS    RESTARTS      AGE
# echo-server-7cbbfd6bbc-c74q7          1/1     Running   0             4m23s
# echo-server-7cbbfd6bbc-vl945          1/1     Running   0             4m23s
# hello-minikube-77b6f68484-b884h       1/1     Running   4 (17m ago)   28m
# learning-resources-578d844d56-44qvl   1/1     Running   0             3m53s
# learning-resources-578d844d56-s2lvl   1/1     Running   0             3m53s
# learning-resources-578d844d56-v72hj   1/1     Running   0             3m53s

# %%
# !kubectl get pods -n frontend
# Out:
# NAME                       READY   STATUS    RESTARTS   AGE
# frontend-7b6dbd6f5-ddgqf   1/1     Running   0          29s
# frontend-7b6dbd6f5-gssq8   1/1     Running   0          29s
# frontend-7b6dbd6f5-rgmvz   1/1     Running   0          29s
